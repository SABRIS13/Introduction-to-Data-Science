# %% [markdown]
# # Sesión 2

# %%
import csv

# %%
csvfile=open("data-text.csv","r")
reader=csv.reader(csvfile)

# %%
reader

# %%
for row in reader:
    print(row)

# %%
with open('data-text.csv','r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)

# %% [markdown]
# Crear un archivo CSV

# %%
with open('Mis_datos.csv','w', newline="") as file:
    writer=csv.writer(file)

    writer.writerow(["ID","Name","Age"])
    writer.writerow(["001","Jude","17"])
    writer.writerow(["002","Cardan","18"])
    writer.writerow(["003","Viri","20"])
    writer.writerow(["004","Taryn","17"])

# %%
with open('Mis_datos.csv','r') as file:
    reader=csv.reader(file)

    for row in reader:
        print(row[1])
# Out:
# Name
# Jude
# Cardan
# Viri
# Taryn

# %%
# !pip install pandas
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 140, in test_writable_dir
#     return _test_writable_dir_win(path)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 153, in _test_writable_dir_win
#     fd = os.open(file, os.O_RDWR | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: 'c:\\program files\\python36\\Lib\\site-packages\\accesstest_deleteme_fishfingers_custard_u4vs4r'
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python36\python.exe -m pip install --upgrade pip' command.
# Collecting pandas
#   Using cached pandas-1.4.2-cp310-cp310-win_amd64.whl (10.6 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\sabri\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.21.0
#   Using cached numpy-1.22.4-cp310-cp310-win_amd64.whl (14.7 MB)
# Requirement already satisfied: six>=1.5 in c:\users\sabri\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.22.4 pandas-1.4.2 pytz-2022.1
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the 'c:\Users\sabri\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 140, in test_writable_dir
#     return _test_writable_dir_win(path)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 153, in _test_writable_dir_win
#     fd = os.open(file, os.O_RDWR | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: 'c:\\program files\\python36\\Lib\\site-packages\\accesstest_deleteme_fishfingers_custard_27znoj'
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python36\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade pip
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 140, in test_writable_dir
#     return _test_writable_dir_win(path)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 153, in _test_writable_dir_win
#     fd = os.open(file, os.O_RDWR | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: 'c:\\program files\\python36\\Lib\\site-packages\\accesstest_deleteme_fishfingers_custard_uotl3s'
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python36\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
datos=pd.read_csv("Mis_datos.csv")

# %%
datos
# Out:
#    ID    Name  Age
# 0   1    Jude   17
# 1   2  Cardan   18
# 2   3    Viri   20
# 3   4   Taryn   17

# %%
dat=pd.read_csv("data-text.csv")

# %%
dat
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
#                  WHO region World Bank income group               Country  \
# 0                    Europe             High-income               Andorra
# 1                    Europe             High-income               Andorra
# 2                    Europe             High-income               Andorra
# 3                    Europe             High-income               Andorra
# 4     Eastern Mediterranean             High-income  United Arab Emirates
# ...                     ...                     ...                   ...
# 4651        Western Pacific     Lower-middle-income                 Samoa
# 4652  Eastern Mediterranean              Low-income                 Yemen
# 4653                 Africa     Upper-middle-income          South Africa
# 4654                 Africa              Low-income                Zambia
# 4655                 Africa              Low-income              Zimbabwe
#
#              Sex  Display Value  Numeric  Low  High  Comments
# 0     Both sexes             77     77.0  NaN   NaN       NaN
# 1     Both sexes             80     80.0  NaN   NaN       NaN
# 2         Female             28     28.0  NaN   NaN       NaN
# 3     Both sexes             23     23.0  NaN   NaN       NaN
# 4         Female             78     78.0  NaN   NaN       NaN
# ...          ...            ...      ...  ...   ...       ...
# 4651      Female             66     66.0  NaN   NaN       NaN
# 4652  Both sexes             54     54.0  NaN   NaN       NaN
# 4653        Male             49     49.0  NaN   NaN       NaN
# 4654  Both sexes             36     36.0  NaN   NaN       NaN
# 4655      Female             51     51.0  NaN   NaN       NaN
#
# [4656 rows x 12 columns]

# %%
iris=pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# !pip install openpyxl
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 140, in test_writable_dir
#     return _test_writable_dir_win(path)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 153, in _test_writable_dir_win
#     fd = os.open(file, os.O_RDWR | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: 'c:\\program files\\python36\\Lib\\site-packages\\accesstest_deleteme_fishfingers_custard_zrnwoh'
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python36\python.exe -m pip install --upgrade pip' command.

# %%
# !pip3 install openpyxl
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 140, in test_writable_dir
#     return _test_writable_dir_win(path)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 153, in _test_writable_dir_win
#     fd = os.open(file, os.O_RDWR | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: 'c:\\program files\\python36\\Lib\\site-packages\\accesstest_deleteme_fishfingers_custard_g1no52'
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python36\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install openpyxl
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\cli\base_command.py", line 186, in _main
#     status = self.run(options, args)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 258, in run
#     isolated_mode=options.isolated_mode,
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 604, in decide_user_install
#     if site_packages_writable(root=root_path, isolated=isolated_mode):
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in site_packages_writable
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\commands\install.py", line 549, in <genexpr>
#     test_writable_dir(d) for d in set(get_lib_location_guesses(**kwargs))
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 140, in test_writable_dir
#     return _test_writable_dir_win(path)
#   File "c:\program files\python36\lib\site-packages\pip\_internal\utils\filesystem.py", line 153, in _test_writable_dir_win
#     fd = os.open(file, os.O_RDWR | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: 'c:\\program files\\python36\\Lib\\site-packages\\accesstest_deleteme_fishfingers_custard_0h2dzl'
# WARNING: You are using pip version 20.0.2; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\program files\python36\python.exe -m pip install --upgrade pip' command.

# %%
tags = pd.read_excel("tags.xlsx")
tags
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=136'>137</a> try:
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=137'>138</a>     module = importlib.import_module(name)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=138'>139</a> except ImportError:
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=124'>125</a>         level += 1
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=125'>126</a> return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\sabri\Desktop\Modulo 2\Sesión 2\sesion2.ipynb Cell 23' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sabri/Desktop/Modulo%202/Sesi%C3%B3n%202/sesion2.ipynb#ch0000021?line=0'>1</a> tags = pd.read_excel("tags.xlsx")
#       <a href='vscode-notebook-cell:/c%3A/Users/sabri/Desktop/Modulo%202/Sesi%C3%B3n%202/sesion2.ipynb#ch0000021?line=1'>2</a> tags
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=454'>455</a> if not isinstance(io, ExcelFile):
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=455'>456</a>     should_close = True
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=456'>457</a>     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=457'>458</a> elif engine and engine != io.engine:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=458'>459</a>     raise ValueError(
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=459'>460</a>         "Engine should not be specified when passing "
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=460'>461</a>         "an ExcelFile - ExcelFile already has the engine set"
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=461'>462</a>     )
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1415'>1416</a> self.engine = engine
#    <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1416'>1417</a> self.storage_options = storage_options
# -> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1418'>1419</a> self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:524, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=508'>509</a> def __init__(
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=509'>510</a>     self,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=510'>511</a>     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=511'>512</a>     storage_options: StorageOptions = None,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=512'>513</a> ) -> None:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=513'>514</a>     """
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=514'>515</a>     Reader using openpyxl engine.
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=515'>516</a>
#    (...)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=521'>522</a>         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=522'>523</a>     """
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=523'>524</a>     import_optional_dependency("openpyxl")
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=524'>525</a>     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=138'>139</a> except ImportError:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=139'>140</a>     if errors == "raise":
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=140'>141</a>         raise ImportError(msg)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=141'>142</a>     else:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=142'>143</a>         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
tags=pd.read_excel('tags.xlsx','hoja 2')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=136'>137</a> try:
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=137'>138</a>     module = importlib.import_module(name)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=138'>139</a> except ImportError:
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=124'>125</a>         level += 1
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/importlib/__init__.py?line=125'>126</a> return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\sabri\Desktop\Modulo 2\Sesión 2\sesion2.ipynb Cell 23' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sabri/Desktop/Modulo%202/Sesi%C3%B3n%202/sesion2.ipynb#ch0000028?line=0'>1</a> tags=pd.read_excel('tags.xlsx','hoja 2')
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=454'>455</a> if not isinstance(io, ExcelFile):
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=455'>456</a>     should_close = True
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=456'>457</a>     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=457'>458</a> elif engine and engine != io.engine:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=458'>459</a>     raise ValueError(
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=459'>460</a>         "Engine should not be specified when passing "
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=460'>461</a>         "an ExcelFile - ExcelFile already has the engine set"
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=461'>462</a>     )
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:1419, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1415'>1416</a> self.engine = engine
#    <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1416'>1417</a> self.storage_options = storage_options
# -> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1418'>1419</a> self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:524, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=508'>509</a> def __init__(
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=509'>510</a>     self,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=510'>511</a>     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=511'>512</a>     storage_options: StorageOptions = None,
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=512'>513</a> ) -> None:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=513'>514</a>     """
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=514'>515</a>     Reader using openpyxl engine.
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=515'>516</a>
#    (...)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=521'>522</a>         passed to fsspec for appropriate URLs (see ``_get_filepath_or_buffer``)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=522'>523</a>     """
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=523'>524</a>     import_optional_dependency("openpyxl")
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=524'>525</a>     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=138'>139</a> except ImportError:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=139'>140</a>     if errors == "raise":
# --> <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=140'>141</a>         raise ImportError(msg)
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=141'>142</a>     else:
#     <a href='file:///c%3A/Users/sabri/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/compat/_optional.py?line=142'>143</a>         return None
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
import json

# %%
json_data=open("data-text.json").read()

# %%
json_data

# %%
json.loads(json_data)
# Out:
# [{'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Andorra',
#   'Sex': 'Both sexes',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Andorra',
#   'Sex': 'Both sexes',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Andorra',
#   'Sex': 'Female',
#   'Display Value': 28,
#   'Numeric': 28.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Andorra',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'United Arab Emirates',
#   'Sex': 'Female',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Antigua and Barbuda',
#   'Sex': 'Male',
#   'Display Value': 72,
#   'Numeric': 72.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Antigua and Barbuda',
#   'Sex': 'Male',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Antigua and Barbuda',
#   'Sex': 'Both sexes',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Australia',
#   'Sex': 'Male',
#   'Display Value': 81,
#   'Numeric': 81.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Australia',
#   'Sex': 'Both sexes',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Australia',
#   'Sex': 'Both sexes',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Austria',
#   'Sex': 'Female',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Austria',
#   'Sex': 'Female',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Belgium',
#   'Sex': 'Female',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Bahrain',
#   'Sex': 'Male',
#   'Display Value': 73,
#   'Numeric': 73.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Bahrain',
#   'Sex': 'Female',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Bahrain',
#   'Sex': 'Male',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Bahamas',
#   'Sex': 'Male',
#   'Display Value': 72,
#   'Numeric': 72.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Bahamas',
#   'Sex': 'Both sexes',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Barbados',
#   'Sex': 'Male',
#   'Display Value': 71,
#   'Numeric': 71.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Barbados',
#   'Sex': 'Female',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Barbados',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Brunei Darussalam',
#   'Sex': 'Female',
#   'Display Value': 20,
#   'Numeric': 20.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Brunei Darussalam',
#   'Sex': 'Female',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Brunei Darussalam',
#   'Sex': 'Female',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Canada',
#   'Sex': 'Female',
#   'Display Value': 82,
#   'Numeric': 82.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Canada',
#   'Sex': 'Male',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Canada',
#   'Sex': 'Female',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Switzerland',
#   'Sex': 'Male',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Switzerland',
#   'Sex': 'Both sexes',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Switzerland',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Cook Islands',
#   'Sex': 'Both sexes',
#   'Display Value': 76,
#   'Numeric': 76.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Cook Islands',
#   'Sex': 'Female',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Cook Islands',
#   'Sex': 'Both sexes',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Cyprus',
#   'Sex': 'Female',
#   'Display Value': 79,
#   'Numeric': 79.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Cyprus',
#   'Sex': 'Both sexes',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Cyprus',
#   'Sex': 'Female',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Cyprus',
#   'Sex': 'Female',
#   'Display Value': 26,
#   'Numeric': 26.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Czech Republic',
#   'Sex': 'Male',
#   'Display Value': 75,
#   'Numeric': 75.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Czech Republic',
#   'Sex': 'Female',
#   'Display Value': 75,
#   'Numeric': 75.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Germany',
#   'Sex': 'Female',
#   'Display Value': 79,
#   'Numeric': 79.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Germany',
#   'Sex': 'Male',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Germany',
#   'Sex': 'Male',
#   'Display Value': 20,
#   'Numeric': 20.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Denmark',
#   'Sex': 'Both sexes',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Denmark',
#   'Sex': 'Male',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Denmark',
#   'Sex': 'Male',
#   'Display Value': 19,
#   'Numeric': 19.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Denmark',
#   'Sex': 'Both sexes',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Denmark',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Spain',
#   'Sex': 'Both sexes',
#   'Display Value': 82,
#   'Numeric': 82.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Spain',
#   'Sex': 'Female',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Spain',
#   'Sex': 'Both sexes',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Estonia',
#   'Sex': 'Female',
#   'Display Value': 75,
#   'Numeric': 75.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Estonia',
#   'Sex': 'Female',
#   'Display Value': 81,
#   'Numeric': 81.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Estonia',
#   'Sex': 'Male',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Estonia',
#   'Sex': 'Female',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Estonia',
#   'Sex': 'Female',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Finland',
#   'Sex': 'Female',
#   'Display Value': 79,
#   'Numeric': 79.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Finland',
#   'Sex': 'Male',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'France',
#   'Sex': 'Male',
#   'Display Value': 75,
#   'Numeric': 75.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'France',
#   'Sex': 'Male',
#   'Display Value': 20,
#   'Numeric': 20.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Sex': 'Female',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Sex': 'Both sexes',
#   'Display Value': 81,
#   'Numeric': 81.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'United Kingdom of Great Britain and Northern Ireland',
#   'Sex': 'Male',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Country': 'Equatorial Guinea',
#   'Sex': 'Female',
#   'Display Value': 52,
#   'Numeric': 52.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Country': 'Equatorial Guinea',
#   'Sex': 'Female',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'High-income',
#   'Country': 'Equatorial Guinea',
#   'Sex': 'Female',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Greece',
#   'Sex': 'Male',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Greece',
#   'Sex': 'Female',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Croatia',
#   'Sex': 'Both sexes',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Croatia',
#   'Sex': 'Male',
#   'Display Value': 16,
#   'Numeric': 16.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Croatia',
#   'Sex': 'Both sexes',
#   'Display Value': 19,
#   'Numeric': 19.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Hungary',
#   'Sex': 'Male',
#   'Display Value': 68,
#   'Numeric': 68.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Hungary',
#   'Sex': 'Both sexes',
#   'Display Value': 72,
#   'Numeric': 72.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Hungary',
#   'Sex': 'Male',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Hungary',
#   'Sex': 'Female',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Hungary',
#   'Sex': 'Both sexes',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Ireland',
#   'Sex': 'Both sexes',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Ireland',
#   'Sex': 'Both sexes',
#   'Display Value': 19,
#   'Numeric': 19.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Ireland',
#   'Sex': 'Both sexes',
#   'Display Value': 20,
#   'Numeric': 20.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Iceland',
#   'Sex': 'Female',
#   'Display Value': 84,
#   'Numeric': 84.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Iceland',
#   'Sex': 'Female',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Israel',
#   'Sex': 'Male',
#   'Display Value': 75,
#   'Numeric': 75.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Israel',
#   'Sex': 'Male',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Israel',
#   'Sex': 'Both sexes',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Italy',
#   'Sex': 'Male',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Italy',
#   'Sex': 'Male',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Italy',
#   'Sex': 'Male',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Italy',
#   'Sex': 'Both sexes',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Japan',
#   'Sex': 'Female',
#   'Display Value': 29,
#   'Numeric': 29.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Japan',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Japan',
#   'Sex': 'Both sexes',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Republic of Korea',
#   'Sex': 'Female',
#   'Display Value': 76,
#   'Numeric': 76.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Republic of Korea',
#   'Sex': 'Both sexes',
#   'Display Value': 72,
#   'Numeric': 72.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Republic of Korea',
#   'Sex': 'Female',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Kuwait',
#   'Sex': 'Male',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Kuwait',
#   'Sex': 'Female',
#   'Display Value': 76,
#   'Numeric': 76.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Kuwait',
#   'Sex': 'Female',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Luxembourg',
#   'Sex': 'Male',
#   'Display Value': 75,
#   'Numeric': 75.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Luxembourg',
#   'Sex': 'Both sexes',
#   'Display Value': 82,
#   'Numeric': 82.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Luxembourg',
#   'Sex': 'Male',
#   'Display Value': 20,
#   'Numeric': 20.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Luxembourg',
#   'Sex': 'Both sexes',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Monaco',
#   'Sex': 'Both sexes',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Monaco',
#   'Sex': 'Both sexes',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Malta',
#   'Sex': 'Female',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Malta',
#   'Sex': 'Female',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Malta',
#   'Sex': 'Both sexes',
#   'Display Value': 76,
#   'Numeric': 76.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Malta',
#   'Sex': 'Female',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Norway',
#   'Sex': 'Male',
#   'Display Value': 76,
#   'Numeric': 76.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Norway',
#   'Sex': 'Female',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Nauru',
#   'Sex': 'Male',
#   'Display Value': 73,
#   'Numeric': 73.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Nauru',
#   'Sex': 'Both sexes',
#   'Display Value': 73,
#   'Numeric': 73.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Nauru',
#   'Sex': 'Both sexes',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'Nauru',
#   'Sex': 'Female',
#   'Display Value': 27,
#   'Numeric': 27.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'New Zealand',
#   'Sex': 'Both sexes',
#   'Display Value': 79,
#   'Numeric': 79.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Western Pacific',
#   'World Bank income group': 'High-income',
#   'Country': 'New Zealand',
#   'Sex': 'Female',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Oman',
#   'Sex': 'Male',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Oman',
#   'Sex': 'Female',
#   'Display Value': 70,
#   'Numeric': 70.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Oman',
#   'Sex': 'Female',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Oman',
#   'Sex': 'Male',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Oman',
#   'Sex': 'Female',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Oman',
#   'Sex': 'Female',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Portugal',
#   'Sex': 'Male',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Portugal',
#   'Sex': 'Both sexes',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Qatar',
#   'Sex': 'Male',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Qatar',
#   'Sex': 'Male',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Qatar',
#   'Sex': 'Both sexes',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Qatar',
#   'Sex': 'Both sexes',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'High-income',
#   'Country': 'Saudi Arabia',
#   'Sex': 'Both sexes',
#   'Display Value': 73,
#   'Numeric': 73.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Male',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Male',
#   'Display Value': 82,
#   'Numeric': 82.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Female',
#   'Display Value': 85,
#   'Numeric': 85.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Male',
#   'Display Value': 20,
#   'Numeric': 20.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Male',
#   'Display Value': 22,
#   'Numeric': 22.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Female',
#   'Display Value': 25,
#   'Numeric': 25.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovakia',
#   'Sex': 'Male',
#   'Display Value': 66,
#   'Numeric': 66.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovakia',
#   'Sex': 'Both sexes',
#   'Display Value': 73,
#   'Numeric': 73.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovakia',
#   'Sex': 'Both sexes',
#   'Display Value': 76,
#   'Numeric': 76.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Male',
#   'Display Value': 70,
#   'Numeric': 70.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Female',
#   'Display Value': 83,
#   'Numeric': 83.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Both sexes',
#   'Display Value': 74,
#   'Numeric': 74.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Both sexes',
#   'Display Value': 19,
#   'Numeric': 19.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Sweden',
#   'Sex': 'Both sexes',
#   'Display Value': 78,
#   'Numeric': 78.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Trinidad and Tobago',
#   'Sex': 'Male',
#   'Display Value': 67,
#   'Numeric': 67.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Trinidad and Tobago',
#   'Sex': 'Female',
#   'Display Value': 71,
#   'Numeric': 71.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Trinidad and Tobago',
#   'Sex': 'Female',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Country': 'Afghanistan',
#   'Sex': 'Both sexes',
#   'Display Value': 55,
#   'Numeric': 55.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Country': 'Afghanistan',
#   'Sex': 'Female',
#   'Display Value': 16,
#   'Numeric': 16.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Country': 'Afghanistan',
#   'Sex': 'Female',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burundi',
#   'Sex': 'Female',
#   'Display Value': 51,
#   'Numeric': 51.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burundi',
#   'Sex': 'Male',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Male',
#   'Display Value': 51,
#   'Numeric': 51.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Male',
#   'Display Value': 53,
#   'Numeric': 53.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Male',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Both sexes',
#   'Display Value': 16,
#   'Numeric': 16.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burkina Faso',
#   'Sex': 'Male',
#   'Display Value': 48,
#   'Numeric': 48.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
# ...
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Both sexes',
#   'Display Value': 82,
#   'Numeric': 82.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Both sexes',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'San Marino',
#   'Sex': 'Both sexes',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovakia',
#   'Sex': 'Female',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Male',
#   'Display Value': 72,
#   'Numeric': 72.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Male',
#   'Display Value': 77,
#   'Numeric': 77.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Female',
#   'Display Value': 80,
#   'Numeric': 80.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Male',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Slovenia',
#   'Sex': 'Female',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Sweden',
#   'Sex': 'Both sexes',
#   'Display Value': 82,
#   'Numeric': 82.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Europe',
#   'World Bank income group': 'High-income',
#   'Country': 'Sweden',
#   'Sex': 'Both sexes',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Trinidad and Tobago',
#   'Sex': 'Both sexes',
#   'Display Value': 68,
#   'Numeric': 68.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Trinidad and Tobago',
#   'Sex': 'Both sexes',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'Trinidad and Tobago',
#   'Sex': 'Both sexes',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'United States of America',
#   'Sex': 'Female',
#   'Display Value': 23,
#   'Numeric': 23.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'United States of America',
#   'Sex': 'Female',
#   'Display Value': 24,
#   'Numeric': 24.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Americas',
#   'World Bank income group': 'High-income',
#   'Country': 'United States of America',
#   'Sex': 'Both sexes',
#   'Display Value': 21,
#   'Numeric': 21.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Country': 'Afghanistan',
#   'Sex': 'Male',
#   'Display Value': 49,
#   'Numeric': 49.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Country': 'Afghanistan',
#   'Sex': 'Male',
#   'Display Value': 58,
#   'Numeric': 58.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Eastern Mediterranean',
#   'World Bank income group': 'Low-income',
#   'Country': 'Afghanistan',
#   'Sex': 'Male',
#   'Display Value': 14,
#   'Numeric': 14.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burundi',
#   'Sex': 'Male',
#   'Display Value': 14,
#   'Numeric': 14.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burundi',
#   'Sex': 'Both sexes',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Female',
#   'Display Value': 56,
#   'Numeric': 56.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Female',
#   'Display Value': 60,
#   'Numeric': 60.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Female',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Both sexes',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Benin',
#   'Sex': 'Both sexes',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burkina Faso',
#   'Sex': 'Female',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Burkina Faso',
#   'Sex': 'Female',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Country': 'Bangladesh',
#   'Sex': 'Female',
#   'Display Value': 59,
#   'Numeric': 59.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Country': 'Bangladesh',
#   'Sex': 'Male',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Country': 'Bangladesh',
#   'Sex': 'Male',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'South-East Asia',
#   'World Bank income group': 'Low-income',
#   'Country': 'Bangladesh',
#   'Sex': 'Both sexes',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Central African Republic',
#   'Sex': 'Both sexes',
#   'Display Value': 51,
#   'Numeric': 51.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Central African Republic',
#   'Sex': 'Male',
#   'Display Value': 14,
#   'Numeric': 14.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Democratic Republic of the Congo',
#   'Sex': 'Female',
#   'Display Value': 53,
#   'Numeric': 53.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Democratic Republic of the Congo',
#   'Sex': 'Female',
#   'Display Value': 16,
#   'Numeric': 16.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Democratic Republic of the Congo',
#   'Sex': 'Both sexes',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Comoros',
#   'Sex': 'Both sexes',
#   'Display Value': 56,
#   'Numeric': 56.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Comoros',
#   'Sex': 'Female',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Comoros',
#   'Sex': 'Both sexes',
#   'Display Value': 15,
#   'Numeric': 15.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Eritrea',
#   'Sex': 'Male',
#   'Display Value': 39,
#   'Numeric': 39.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Eritrea',
#   'Sex': 'Female',
#   'Display Value': 50,
#   'Numeric': 50.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Eritrea',
#   'Sex': 'Female',
#   'Display Value': 13,
#   'Numeric': 13.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ethiopia',
#   'Sex': 'Male',
#   'Display Value': 50,
#   'Numeric': 50.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ethiopia',
#   'Sex': 'Male',
#   'Display Value': 14,
#   'Numeric': 14.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ethiopia',
#   'Sex': 'Male',
#   'Display Value': 17,
#   'Numeric': 17.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2000,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ethiopia',
#   'Sex': 'Both sexes',
#   'Display Value': 16,
#   'Numeric': 16.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at age 60 (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ethiopia',
#   'Sex': 'Both sexes',
#   'Display Value': 18,
#   'Numeric': 18.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ghana',
#   'Sex': 'Male',
#   'Display Value': 55,
#   'Numeric': 55.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 1990,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ghana',
#   'Sex': 'Both sexes',
#   'Display Value': 57,
#   'Numeric': 57.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  {'Indicator': 'Life expectancy at birth (years)',
#   'PUBLISH STATES': 'Published',
#   'Year': 2012,
#   'WHO region': 'Africa',
#   'World Bank income group': 'Low-income',
#   'Country': 'Ghana',
#   'Sex': 'Both sexes',
#   'Display Value': 62,
#   'Numeric': 62.0,
#   'Low': '',
#   'High': '',
#   'Comments': ''},
#  ...]

# %% [markdown]
# Lecturas txt

# %%
import urllib.request

# %%
url="https://www.gutenberg.org/files/1112/1112.txt"
response=urllib.request.urlopen(url)

# %%
response

# %%
text=response.read().decode()

# %%
text[0:500]
# Out:
# "The Project Gutenberg EBook of Romeo and Juliet, by William Shakespeare\r\n\r\n\r\n*******************************************************************\r\nTHIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A\r\nTIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE\r\nIS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK\r\n(#1513) at https://www.gutenberg.org/ebooks/1513\r\n*******************************************************************\r\n\r\n\r\nThis eBook is for the use "
